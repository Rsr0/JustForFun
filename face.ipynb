# %% [markdown]
# <a href="https://colab.research.google.com/github/Rsr0/JustForFun/blob/main/face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate faces of person that doesn't exist!
#
# *https://thispersondoesnotexist.com/*

# %%
# !pip install random_face

# %%
import cv2
from google.colab.patches import cv2_imshow
import random_face

engine = random_face.get_engine()
face = engine.get_random_face()
cv2_imshow(face)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F88AF38B6D0>
